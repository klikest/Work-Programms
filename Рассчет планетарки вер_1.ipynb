# %%
import matplotlib.pyplot as plt
import handcalcs.render
import math

PI = math.pi

# %% [markdown]
# Схема с одновенцовыми сателлитами
#
# ![image.png](attachment:image.png)

# %%
# Исходные данные:

P_a = 956    # Мощность, Квт
t_h = 1000  # Время работы, ч
n_a = 10000  # Частота вращения на входе
n_h = 1700   # Частота вращения на выходе

# %% [markdown]
# Рекомендуемые значения передаточных отношений для
# одновенцовых сателлитов i_пл = 3...9 , для двухвенцовых –
# i_пл = 7...16

# %%
# %%render
# i_pl = n_a/n_h
#
#
# i_ag = (i_pl/2) -1
# i_gb = (i_pl-1)/i_ag
#
# n_a_h = n_a-n_h
# n_g_h = n_f_h = n_a_h/i_ag
# n_b_h = n_h
# Out:
# \[
# \begin{aligned}
# i_{pl} &= \frac{ n_{a} }{ n_{h} }  = \frac{ 10000 }{ 1700 } &= 5.882
# \\[10pt]
# i_{ag} &= \left( \frac{ i_{pl} }{ 2 } \right) - 1  = \left( \frac{ 5.882 }{ 2 } \right) - 1 &= 1.941
# \\[10pt]
# i_{gb} &= \frac{ i_{pl} - 1 }{ i_{ag} }  = \frac{ 5.882 - 1 }{ 1.941 } &= 2.515
# \\[10pt]
# n_{a_{h}} &= n_{a} - n_{h}  = 10000 - 1700 &= 8300
# \\[10pt]
# n_{g_{h}} &= n_{f_{h}}  = \frac{ n_{a_{h}} }{ i_{ag} } &= 4275.758 &= \frac{ 8300 }{ 1.941 } &= 4275.758
# \\[10pt]
# n_{b_{h}} &= 1700 \;
# \end{aligned}
# \]

# %%
# %%render
# a_c = (0.9*PI)/math.asin((i_pl-2)/i_pl)
# a_c = math.floor(a_c)
# a_c
# Out:
# \[
# \begin{aligned}
# a_{c} &= \frac{ 0.9 \cdot \mathrm{PI} }{ \mathrm{math.asin} { \left( \frac{ i_{pl} - 2 }{ i_{pl} } \right) } }  = \frac{ 0.9 \cdot 3.142 }{ math.asin { \left( \frac{ 5.882 - 2 }{ 5.882 } \right) } } &= 3
# \\[10pt]
# a_{c} &= \mathrm{math.floor} { a_{c} }  = math.floor { 3 } &= 3
# \\[10pt]
# a_{c} &= 3 \;
# \end{aligned}
# \]

# %%
# %%render
# T_a = 9550 * (P_a/n_a) * 1000
# T_a
# Out:
# \[
# \begin{aligned}
# T_{a} &= 9550 \cdot \left( \frac{ P_{a} }{ n_{a} } \right) \cdot 1000  = 9550 \cdot \left( \frac{ 956 }{ 10000 } \right) \cdot 1000 &= 912980.000
# \\[10pt]
# T_{a} &= 912980.000 \;
# \end{aligned}
# \]

# %%
# %%render
# T_ag =(T_a * 1.1)/a_c
# T_ag
# Out:
# \[
# \begin{aligned}
# T_{ag} &= \frac{ T_{a} \cdot 1.1 }{ a_{c} }  = \frac{ 912980.000 \cdot 1.1 }{ 3 } &= 334759.333
# \\[10pt]
# T_{ag} &= 334759.333 \;
# \end{aligned}
# \]

# %%
# %%render
# T_gb =T_ag*i_ag*0.99
# T_gb
# Out:
# \[
# \begin{aligned}
# T_{gb} &= T_{ag} \cdot i_{ag} \cdot 0.99  = 334759.333 \cdot 1.941 \cdot 0.99 &= 643328.672
# \\[10pt]
# T_{gb} &= 643328.672 \;
# \end{aligned}
# \]

# %%
# %%render
# HB = 600
# K_HE = 1
# C = a_c
# S_H = 1.2
# N_H0 = 30*HB**2.4
# N_HE = 60*C*n_a_h*t_h*K_HE
# K_HL = 1
# sigma_H_lim_b = 1380
# sigma_H_a = (sigma_H_lim_b/S_H)*K_HL
#
#
# N_HE = 60*C*n_g_h*t_h*K_HE
# K_HL = 1
# sigma_H_g = (sigma_H_lim_b/S_H)*K_HL
#
# N_HE = 60*C*n_b_h*t_h*K_HE
# K_HL = 1
# sigma_H_h = (sigma_H_lim_b/S_H)*K_HL
#
# sigma_H_min = min([sigma_H_a, sigma_H_g, sigma_H_h])
# Out:
# \[
# \begin{aligned}
# \mathrm{HB} &= 600 \;
# \\[10pt]
# K_{HE} &= 1 \;
# \\[10pt]
# C &= 3 \;
# \\[10pt]
# S_{H} &= 1.200 \;
# \\[10pt]
# N_{H0} &= 30 \cdot \left( \mathrm{HB} \right) ^{ 2.4 }  = 30 \cdot \left( 600 \right) ^{ 2.4 } &= 139535353.075
# \\[10pt]
# N_{HE} &= 60 \cdot C \cdot n_{a_{h}} \cdot t_{h} \cdot K_{HE}  = 60 \cdot 3 \cdot 8300 \cdot 1000 \cdot 1 &= 306000000
# \\[10pt]
# K_{HL} &= 1 \;
# \\[10pt]
# \sigma_{H_{lim_{b}}} &= 1380 \;
# \\[10pt]
# \sigma_{H_{a}} &= \left( \frac{ \sigma_{H_{lim_{b}}} }{ S_{H} } \right) \cdot K_{HL}  = \left( \frac{ 1380 }{ 1.200 } \right) \cdot 1 &= 1150.000
# \\[10pt]
# N_{HE} &= 60 \cdot C \cdot n_{g_{h}} \cdot t_{h} \cdot K_{HE}  = 60 \cdot 3 \cdot 4275.758 \cdot 1000 \cdot 1 &= 306000000
# \\[10pt]
# K_{HL} &= 1 \;
# \\[10pt]
# \sigma_{H_{g}} &= \left( \frac{ \sigma_{H_{lim_{b}}} }{ S_{H} } \right) \cdot K_{HL}  = \left( \frac{ 1380 }{ 1.200 } \right) \cdot 1 &= 1150.000
# \\[10pt]
# ...

# %%
# %%render
#
# sigma_H_a
# sigma_H_g
# sigma_H_h
#
#
# sigma_H_min
# Out:
# \[
# \begin{aligned}
# \sigma_{H_{a}} &= 1150.000 \;
# \\[10pt]
# \sigma_{H_{g}} &= 1150.000 \;
# \\[10pt]
# \sigma_{H_{h}} &= 1150.000 \;
# \\[10pt]
# \sigma_{H_{min}} &= 1150.000 \;
# \end{aligned}
# \]

# %%
# %%render
# sigma_F_lim_b = 850
# S_F = 2
# K_FL_1 = ((4*10**6) / (60*4*n_a_h*t_h))**(1/40)
# K_FC = 0.8
# sigma_F_a = (sigma_F_lim_b/S_F)*K_FL_1*K_FC
#
# K_FL_2 = ((4*10**6) / (60*4*n_g_h*t_h*1))**(1/40)
# sigma_F_g = (sigma_F_lim_b/S_F)*K_FL_2*K_FC
#
# K_FL = ((4*10**6) / (60*4*n_b_h*t_h*1))**(1/40)
# sigma_F_h = (sigma_F_lim_b/S_F)*K_FL*K_FC
#
# sigma_F_min = min([sigma_F_a, sigma_F_g, sigma_F_h])
# Out:
# \[
# \begin{aligned}
# \sigma_{F_{lim_{b}}} &= 850 \;
# \\[10pt]
# S_{F} &= 2 \;
# \\[10pt]
# K_{FL_{1}} &= \left( \frac{ 4 \cdot \left( 10 \right) ^{ 6 } }{ 60 \cdot 4 \cdot n_{a_{h}} \cdot t_{h} } \right) ^{ \left( \frac{ 1 }{ 40 } \right) } \\&= \left( \frac{ 4 \cdot \left( 10 \right) ^{ 6 } }{ 60 \cdot 4 \cdot 8300 \cdot 1000 } \right) ^{ \left( \frac{ 1 }{ 40 } \right) } \\&= 0.856  \\[10pt]
# \\[10pt]
# K_{FC} &= 0.800 \;
# \\[10pt]
# \sigma_{F_{a}} &= \left( \frac{ \sigma_{F_{lim_{b}}} }{ S_{F} } \right) \cdot K_{FL_{1}} \cdot K_{FC}  = \left( \frac{ 850 }{ 2 } \right) \cdot 0.856 \cdot 0.800 &= 291.104
# \\[10pt]
# K_{FL_{2}} &= \left( \frac{ 4 \cdot \left( 10 \right) ^{ 6 } }{ 60 \cdot 4 \cdot n_{g_{h}} \cdot t_{h} \cdot 1 } \right) ^{ \left( \frac{ 1 }{ 40 } \right) } \\&= \left( \frac{ 4 \cdot \left( 10 \right) ^{ 6 } }{ 60 \cdot 4 \cdot 4275.758 \cdot 1000 \cdot 1 } \right) ^{ \left( \frac{ 1 }{ 40 } \right) } \\&= 0.871  \\[10pt]
# \\[10pt]
# ...

# %%
# %%render
# sigma_F_a
# sigma_F_g
# sigma_F_h
#
# sigma_F_min
# Out:
# \[
# \begin{aligned}
# \sigma_{F_{a}} &= 291.104 \;
# \\[10pt]
# \sigma_{F_{g}} &= 295.971 \;
# \\[10pt]
# \sigma_{F_{h}} &= 302.875 \;
# \\[10pt]
# \sigma_{F_{min}} &= 291.104 \;
# \end{aligned}
# \]

# %%
# %%render
# K_H = 1.3
# psi_bd = 0.8
#
#
# d_a = 77*((T_ag*K_H*(i_ag+1)) / (psi_bd * sigma_H_a**2 * i_ag))**(1/3)
# Out:
# \[
# \begin{aligned}
# K_{H} &= 1.300 \;
# \\[10pt]
# \psi_{bd} &= 0.800 \;
# \\[10pt]
# d_{a} &= 77 \cdot \left( \frac{ T_{ag} \cdot K_{H} \cdot \left( i_{ag} + 1 \right) }{ \psi_{bd} \cdot \left( \sigma_{H_{a}} \right) ^{ 2 } \cdot i_{ag} } \right) ^{ \left( \frac{ 1 }{ 3 } \right) } \\&= 77 \cdot \left( \frac{ 334759.333 \cdot 1.300 \cdot \left( 1.941 + 1 \right) }{ 0.800 \cdot \left( 1150.000 \right) ^{ 2 } \cdot 1.941 } \right) ^{ \left( \frac{ 1 }{ 3 } \right) } \\&= 65.772  \\[10pt]
# \end{aligned}
# \]

# %%
# %%render
# b_1 = psi_bd*d_a
# b_1 = round(b_1)
# Out:
# \[
# \begin{aligned}
# b_{1} &= \psi_{bd} \cdot d_{a}  = 0.800 \cdot 65.772 &= 53
# \\[10pt]
# b_{1} &= \operatorname{round} { \left( b_{1} \right) }  = \operatorname{round} { \left( 53 \right) } &= 53
# \end{aligned}
# \]

# %%
# %%render
#
# a_w = (d_a*(i_ag+1))/2
# d_g = d_a*i_ag
# b2 = 77**3 * ((T_gb*K_H*(i_gb-1)) / ( sigma_H_g**2 *d_g**2 * i_gb))
# Out:
# \[
# \begin{aligned}
# a_{w} &= \frac{ d_{a} \cdot \left( i_{ag} + 1 \right) }{ 2 }  = \frac{ 65.772 \cdot \left( 1.941 + 1 \right) }{ 2 } &= 96.723
# \\[10pt]
# d_{g} &= d_{a} \cdot i_{ag}  = 65.772 \cdot 1.941 &= 127.675
# \\[10pt]
# \mathrm{b2} &= \left( 77 \right) ^{ 3 } \cdot \left( \frac{ T_{gb} \cdot K_{H} \cdot \left( i_{gb} - 1 \right) }{ \left( \sigma_{H_{g}} \right) ^{ 2 } \cdot \left( d_{g} \right) ^{ 2 } \cdot i_{gb} } \right) \\&= \left( 77 \right) ^{ 3 } \cdot \left( \frac{ 643328.672 \cdot 1.300 \cdot \left( 2.515 - 1 \right) }{ \left( 1150.000 \right) ^{ 2 } \cdot \left( 127.675 \right) ^{ 2 } \cdot 2.515 } \right) \\&= 10.669  \\[10pt]
# \end{aligned}
# \]

# %%
# %%render
# K_F = 1.2
# Y_F = 4
# m_H = 760 * ((T_gb/1000*1.2*(i_pl+1)) / (i_pl*a_c*psi_bd*sigma_H_min**2))**(1/3)
# Out:
# \[
# \begin{aligned}
# K_{F} &= 1.200 \;
# \\[10pt]
# Y_{F} &= 4 \;
# \\[10pt]
# m_{H} &= 760 \cdot \left( \frac{ \frac{ T_{gb} }{ 1000 } \cdot 1.2 \cdot \left( i_{pl} + 1 \right) }{ i_{pl} \cdot a_{c} \cdot \psi_{bd} \cdot \left( \sigma_{H_{min}} \right) ^{ 2 } } \right) ^{ \left( \frac{ 1 }{ 3 } \right) } \\&= 760 \cdot \left( \frac{ \frac{ 643328.672 }{ 1000 } \cdot 1.2 \cdot \left( 5.882 + 1 \right) }{ 5.882 \cdot 3 \cdot 0.800 \cdot \left( 1150.000 \right) ^{ 2 } } \right) ^{ \left( \frac{ 1 }{ 3 } \right) } \\&= 49.989  \\[10pt]
# \end{aligned}
# \]
